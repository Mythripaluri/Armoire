# %%
# !pip install --upgrade --no-cache-dir gdown
# !pip install rembg[gpu] gradio==3.45.0

# %%
! wget -c "https://github.com/Kitware/CMake/releases/download/v3.19.6/cmake-3.19.6.tar.gz"
! tar xf cmake-3.19.6.tar.gz
! cd cmake-3.19.6 && ./configure && make && sudo make install
# Out:
# --2025-09-18 13:22:34--  https://github.com/Kitware/CMake/releases/download/v3.19.6/cmake-3.19.6.tar.gz
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# Install library
! sudo apt-get --assume-yes update
! sudo apt-get --assume-yes install build-essential
# OpenCV
! sudo apt-get --assume-yes install libopencv-dev
# General dependencies
! sudo apt-get --assume-yes install libatlas-base-dev libprotobuf-dev libleveldb-dev libsnappy-dev libhdf5-serial-dev protobuf-compiler
! sudo apt-get --assume-yes install --no-install-recommends libboost-all-dev
# Remaining dependencies, 14.04
! sudo apt-get --assume-yes install libgflags-dev libgoogle-glog-dev liblmdb-dev
# Python3 libs
! sudo apt-get --assume-yes install python3-setuptools python3-dev build-essential
! sudo apt-get --assume-yes install python3-pip
! sudo -H pip3 install --upgrade protobuf opencv-python
# OpenCL Generic
! sudo apt-get --assume-yes install opencl-headers ocl-icd-opencl-dev
! sudo apt-get --assume-yes install libviennacl-dev
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:6 https://cli.github.com/packages stable InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,327 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,496 kB]
# ...

# %%
ver_openpose = "v1.7.0"
! echo $ver_openpose
# Out:
# v1.7.0

# %%
! git clone  --depth 1 -b "$ver_openpose" https://github.com/CMU-Perceptual-Computing-Lab/openpose.git
# Out:
# fatal: destination path 'openpose' already exists and is not an empty directory.

# %%
# manually downloading openpose models
# %%bash
gdown 1I4UWTXN5RjtmcmUy6oKUzdUAfD1haNYC
unzip models.zip
mv /content/models/face/pose_iter_116000.caffemodel /content/openpose/models/face/pose_iter_116000.caffemodel
mv /content/models/hand/pose_iter_102000.caffemodel /content/openpose/models/hand/pose_iter_102000.caffemodel
mv /content/models/pose/body_25/pose_iter_584000.caffemodel /content/openpose/models/pose/body_25/pose_iter_584000.caffemodel
mv /content/models/pose/coco/pose_iter_440000.caffemodel /content/openpose/models/pose/coco/pose_iter_440000.caffemodel
mv /content/models/pose/mpi/pose_iter_160000.caffemodel /content/openpose/models/pose/mpi/pose_iter_160000.caffemodel
rm -rf models
rm models.zip
# Out:
# Archive:  models.zip
#    creating: models/
#    creating: models/pose/
#    creating: models/pose/coco/
#  extracting: models/pose/coco/pose_iter_440000.caffemodel
#  extracting: models/pose/coco/main.html
#    creating: models/pose/mpi/
#  extracting: models/pose/mpi/pose_iter_160000.caffemodel
#    creating: models/pose/body_25/
#  extracting: models/pose/body_25/pose_iter_584000.caffemodel
#  extracting: models/pose/body_25/training_results_source.txt
#  extracting: models/pose/body_25/training_log.txt
#    creating: models/pose/body_21a_video/
#  extracting: models/pose/body_21a_video/pose_deploy.prototxt
#  extracting: models/pose/body_21a_video/pose_iter_264000.caffemodel
#    creating: models/pose/1_25BSuperModel11FullVGG/
#    creating: models/pose/1_25BSuperModel11FullVGG/body_25b/
#  extracting: models/pose/1_25BSuperModel11FullVGG/body_25b/training_log.txt
#  extracting: models/pose/1_25BSuperModel11FullVGG/body_25b/pose_iter_636000.caffemodel
# ...

# %%
! cd openpose && mkdir build && cd build
# Out:
# mkdir: cannot create directory ‘build’: File exists

# %%
! cd openpose/build && cmake -DUSE_CUDNN=OFF -DBUILD_PYTHON=ON ..
# Out:
# -- GCC detected, adding compile flags
# -- GCC detected, adding compile flags
# -- Building with CUDA.
# -- CUDA detected: 12.5
# -- Automatic GPU detection failed. Building for all known architectures.
# -- Added CUDA NVCC flags for: sm_35 sm_37 sm_50 sm_52 sm_53 sm_60 sm_61 sm_62 sm_70 sm_72 sm_75 sm_80 sm_86
# -- Found cuDNN: ver. 9.2.1 found (include: /usr/include, library: /usr/lib/x86_64-linux-gnu/libcudnn.so)
# -- Found gflags  (include: /usr/include, library: /usr/lib/x86_64-linux-gnu/libgflags.so)
# -- Found glog    (include: /usr/include, library: /usr/lib/x86_64-linux-gnu/libglog.so)
# -- Caffe will be downloaded from source now. NOTE: This process might take several minutes depending
#         on your internet connection.
# -- Caffe has already been downloaded.
# HEAD is now at 1807aada Added Ampere arch's (CUDA11)
# -- Caffe will be built from source now.
# -- Download the models.
# -- Downloading BODY_25 model...
# -- Model already exists.
# ...

# %%
! cd openpose/build && make -j`nproc`
! cd openpose && mkdir output
# Out:
# [ 12%] Performing build step for 'openpose_lib'
# [  1%] Built target caffeproto
# [  1%] Building NVCC (Device) object src/caffe/CMakeFiles/cuda_compile_1.dir/util/cuda_compile_1_generated_math_functions.cu.o
# [  1%] Building NVCC (Device) object src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_absval_layer.cu.o
# nvcc fatal   : Unsupported gpu architecture 'compute_35'
# CMake Error at cuda_compile_1_generated_absval_layer.cu.o.Release.cmake:220 (message):
#   Error generating
#   /content/openpose/build/caffe/src/openpose_lib-build/src/caffe/CMakeFiles/cuda_compile_1.dir/layers/./cuda_compile_1_generated_absval_layer.cu.o
#
#
# nvcc fatal   : Unsupported gpu architecture 'compute_35'
# make[5]: *** [src/caffe/CMakeFiles/caffe.dir/build.make:84: src/caffe/CMakeFiles/cuda_compile_1.dir/layers/cuda_compile_1_generated_absval_layer.cu.o] Error 1
# make[5]: *** Waiting for unfinished jobs....
# ...

# %%
import os
# %cd /content/
# !rm -rf clothes-virtual-try-on
# !git clone https://github.com/practice404/clothes-virtual-try-on.git
os.makedirs("/content/armoire/checkpoints")
# Out:
# /content
# Cloning into 'clothes-virtual-try-on'...
# remote: Enumerating objects: 214, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 214 (delta 38), reused 19 (delta 19), pack-reused 166 (from 2)
# Receiving objects: 100% (214/214), 20.60 MiB | 19.71 MiB/s, done.
# Resolving deltas: 100% (82/82), done.
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipython-input-2233974821.py in <cell line: 0>()
#       3 get_ipython().system('rm -rf clothes-virtual-try-on')
#       4 get_ipython().system('git clone https://github.com/practice404/clothes-virtual-try-on.git')
# ----> 5 os.makedirs("/content/armoire/checkpoints")
#
# /usr/lib/python3.12/os.py in makedirs(name, mode, exist_ok)
#
# FileExistsError: [Errno 17] File exists: '/content/armoire/checkpoints'

# %%
# !gdown --id 18q4lS7cNt1_X8ewCgya1fq0dSk93jTL6 --output /content/armoire/checkpoints/alias_final.pth
# !gdown --id 1uDRPY8gh9sHb3UDonq6ZrINqDOd7pmTz --output /content/armoire/checkpoints/gmm_final.pth
# !gdown --id 1d7lZNLh51Qt5Mi1lXqyi6Asb2ncLrEdC --output /content/armoire/checkpoints/seg_final.pth
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=18q4lS7cNt1_X8ewCgya1fq0dSk93jTL6
# From (redirected): https://drive.google.com/uc?id=18q4lS7cNt1_X8ewCgya1fq0dSk93jTL6&confirm=t&uuid=7aad07c1-8f98-48bc-be1b-b0e130ac2e5f
# To: /content/armoire/checkpoints/alias_final.pth
# 100% 402M/402M [00:04<00:00, 83.6MB/s]
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1uDRPY8gh9sHb3UDonq6ZrINqDOd7pmTz
# To: /content/armoire/checkpoints/gmm_final.pth
# 100% 76.2M/76.2M [00:00<00:00, 105MB/s]
# ...

# %%
# !gdown --id 1ysEoAJNxou7RNuT9iKOxRhjVRNY5RLjx --output /content/armoire/cloth_segm_u2net_latest.pth --no-cookies
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1ysEoAJNxou7RNuT9iKOxRhjVRNY5RLjx
# From (redirected): https://drive.google.com/uc?id=1ysEoAJNxou7RNuT9iKOxRhjVRNY5RLjx&confirm=t&uuid=51fe30fe-eba5-4159-97c0-ccbd53438794
# To: /content/armoire/cloth_segm_u2net_latest.pth
# 100% 177M/177M [00:03<00:00, 45.2MB/s]

# %%
# %cd /content/
# !pip install ninja
# Out:
# /content
# ...

# %%
# !git clone https://github.com/PeikeLi/Self-Correction-Human-Parsing
# %cd Self-Correction-Human-Parsing
# !mkdir checkpoints
# Out:
# fatal: destination path 'Self-Correction-Human-Parsing' already exists and is not an empty directory.
# /content/Self-Correction-Human-Parsing
# mkdir: cannot create directory ‘checkpoints’: File exists

# %%
# downloading LIP dataset model
# !gdown --id 1k4dllHpu0bdx38J7H28rVVLpU-kOHmnH
# !mv /content/Correction/exp-schp-201908261155-lip.pth /content/Correction/checkpoints/final.pth
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1k4dllHpu0bdx38J7H28rVVLpU-kOHmnH
# From (redirected): https://drive.google.com/uc?id=1k4dllHpu0bdx38J7H28rVVLpU-kOHmnH&confirm=t&uuid=07762163-ce63-481b-8a41-3b57ed47d80b
# To: /content/Self-Correction-Human-Parsing/exp-schp-201908261155-lip.pth
# 100% 267M/267M [00:05<00:00, 49.2MB/s]
# mv: cannot stat '/content/Correction/exp-schp-201908261155-lip.pth': No such file or directory

# %%
# %cd /content/
# Out:
# /content

# %%
# !wget -q https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O miniconda.sh
# !bash miniconda.sh -b -f -p $HOME/miniconda
# !$HOME/miniconda/bin/conda --version
# Out:
# PREFIX=/root/miniconda
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /root/miniconda
# conda 25.7.0

# %%
# !/root/miniconda/bin/conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !/root/miniconda/bin/conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
# Out:
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r

# %%
# !/root/miniconda/bin/conda create -y -n py311 python=3.11
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /root/miniconda/envs/py311
#
#   added / updated specs:
#     - python=3.11
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h5eee18b_6
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2025.9.9-h06a4308_0
#   expat              pkgs/main/linux-64::expat-2.7.1-h6a678d5_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.40-h12ee557_0
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
# ...

# %%
# !/root/miniconda/bin/conda install -n py311 -y numpy pandas matplotlib
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /root/miniconda/envs/py311
#
#   added / updated specs:
#     - matplotlib
#     - numpy
#     - pandas
#
#
# The following NEW packages will be INSTALLED:
#
#   aom                pkgs/main/linux-64::aom-3.6.0-h6a678d5_0
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   bottleneck         pkgs/main/linux-64::bottleneck-1.4.2-py311hf4808d0_0
#   brotli-python      pkgs/main/linux-64::brotli-python-1.0.9-py311h6a678d5_9
#   cairo              pkgs/main/linux-64::cairo-1.18.4-h44eff21_0
#   contourpy          pkgs/main/linux-64::contourpy-1.3.1-py311hdb19cb5_0
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   cyrus-sasl         pkgs/main/linux-64::cyrus-sasl-2.1.28-h1110e0f_3
#   dav1d              pkgs/main/linux-64::dav1d-1.2.1-h5eee18b_0
# ...

# %%
# !/root/miniconda/bin/python -m ipykernel install --user --name=py311 --display-name "Python 3.11 (Conda)"
# Out:
# /root/miniconda/bin/python: No module named ipykernel

# %%
# !python --version
import sys
sys.executable
# !{sys.executable} -m site
# Out:
# Python 3.12.11
# sys.path = [
#     '/content',
#     '/env/python',
#     '/usr/lib/python312.zip',
#     '/usr/lib/python3.12',
#     '/usr/lib/python3.12/lib-dynload',
#     '/usr/local/lib/python3.12/dist-packages',
#     '/usr/lib/python3/dist-packages',
# ]
# USER_BASE: '/root/.local' (exists)
# USER_SITE: '/root/.local/lib/python3.12/site-packages' (doesn't exist)
# ENABLE_USER_SITE: True

# %%
# !pip install numpy pandas matplotlib

# %%
# !pip install featuretools --upgrade

# %%
# !pip install opencv-python torchgeometry

# %%
import os
from PIL import Image

def make_dir():
    os.system("cd /content/ && mkdir -p inputs/test/cloth inputs/test/cloth-mask inputs/test/image inputs/test/image-parse inputs/test/openpose-img inputs/test/openpose-json")

# %%
import gradio as gr
from PIL import Image

def run(cloth, model):
    print("cloth type:", type(cloth))
    print("model type:", type(model))
    if cloth:
        cloth.save("/content/cloth_test.jpg")
    if model:
        model.save("/content/model_test.jpg")
    return cloth

with gr.Blocks() as demo:
    cloth_input = gr.Image(type="pil", label="Upload the Cloth Image", image_mode="RGB")
    model_input = gr.Image(type="pil", label="Upload the Human Image", image_mode="RGB")
    final_output = gr.Image(type="pil", label="Final Prediction")
    submit_button = gr.Button("Submit")

    submit_button.click(fn=run, inputs=[cloth_input, model_input], outputs=[final_output])

demo.launch(debug=True, share=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# IMPORTANT: You are using gradio version 3.45.0, however version 4.44.1 is available, please upgrade.
# --------
# Running on public URL: https://815b2939d4bf707be7.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://815b2939d4bf707be7.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/routes.py", line 517, in predict
#     output = await route_utils.call_process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
import gradio as gr

with gr.Blocks() as app:
    with gr.Row():
        gr.Markdown("<center><h1> Clothes Virtual Try ON </h1><center>")
    with gr.Row():
        with gr.Column():
            cloth_input = gr.Image(type="pil", label="Upload the Cloth Image")
        with gr.Column():
            model_input = gr.Image(type="pil", label="Upload the Human Image")
    with gr.Row():
        final_output = gr.Image(type="pil", label="Final Prediction")
    with gr.Row():
        submit_button = gr.Button("Submit")

    submit_button.click(fn=run, inputs=[cloth_input, model_input], outputs=[final_output])

app.launch(debug=True, share=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# IMPORTANT: You are using gradio version 3.45.0, however version 4.44.1 is available, please upgrade.
# --------
# Running on public URL: https://13a973fedabb264f4b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://13a973fedabb264f4b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/routes.py", line 517, in predict
#     output = await route_utils.call_process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
